# %% [markdown]
# # GSE131907 Dataset Overview
#
# Interactive companion notebook for metadata and composition inspection.

# %%
from pathlib import Path
import pandas as pd

project = Path('..').resolve()
meta = pd.read_csv(project / 'data/metadata/gse131907_cell_metadata_clean.csv')
meta.head()

# %%
pd.crosstab(meta['tissue_site'], meta['cell_type_clean'])
